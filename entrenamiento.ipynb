# %%
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('./dataset/recipes_entrenamiento.csv')

# %%
scaler = StandardScaler()
data_escalada = scaler.fit_transform(data.iloc[:, 6:15].to_numpy())

# %%
model = NearestNeighbors(metric="cosine", algorithm='brute')
model.fit(data_escalada)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
promedios = {
    "calorias": data["Calories"].mean(),
    "grasas": data["FatContent"].mean(),
    "grasas_saturadas": data["SaturatedFatContent"].mean(),
    "colesterol": data["CholesterolContent"].mean(),
    "sodio": data["SodiumContent"].mean(),
    "carbohidratos": data["CarbohydrateContent"].mean(),
    "fibra": data["FiberContent"].mean(),
    "azucares": data["SugarContent"].mean(),
    "proteinas": data["ProteinContent"].mean(),
}

# %%
example = [list(promedios.values())]
example[0][0] =  100
example = scaler.transform(np.array(example))

vecinos = model.kneighbors(example, return_distance=False, n_neighbors=10)

# %%
data.iloc[vecinos[0]]
# Out:
#         RecipeId TotalTime  RecipeCategory  \
# 31993      60723     PT15M       Vegetable
# 281483    480289      PT5M         Berries
# 22328      41427   PT1H45M          Potato
# 80883     146581      PT1H     Savory Pies
# 71248     129628     PT13M       < 15 Mins
# 304034    516199     PT55M           Squid
# 260420    445297   PT1H10M       Vegetable
# 162384    281914      PT1H          Onions
# 97845     175310     PT55M       Vegetable
# 103969    185552     PT50M  Chicken Breast
#
#                                                  Keywords  \
# 31993         ['European', 'Brunch', '< 15 Mins', 'Easy']
# 281483  ['Fruit', 'Low Protein', 'Low Cholesterol', '<...
# 22328   ['Cheese', 'Vegetable', 'Weeknight', 'Oven', '...
# 80883   ['Russian', 'European', '< 60 Mins', 'Easy', '...
# 71248                                             ['asy']
# 304034  ['Cheese', 'No Shell Fish', 'Peppers', 'Vegeta...
# 260420            ['Low Protein', 'Potluck', '< 4 Hours']
# ...

# %%
example
# Out:
# array([[-0.86208659,  0.        ,  0.        ,  0.        ,  0.        ,
#          0.        ,  0.        ,  0.        ,  0.        ]])
