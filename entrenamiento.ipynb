# %%
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('./dataset/recipes_entrenamiento.csv')

# %%
scaler = StandardScaler()
data_escalada = scaler.fit_transform(data.iloc[:, 6:15].to_numpy())

# %%
model = NearestNeighbors(metric="cosine", algorithm='brute')
model.fit(data_escalada)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
promedios = {
    "calorias": data["Calories"].mean(),
    "grasas": data["FatContent"].mean(),
    "grasas_saturadas": data["SaturatedFatContent"].mean(),
    "colesterol": data["CholesterolContent"].mean(),
    "sodio": data["SodiumContent"].mean(),
    "carbohidratos": data["CarbohydrateContent"].mean(),
    "fibra": data["FiberContent"].mean(),
    "azucares": data["SugarContent"].mean(),
    "proteinas": data["ProteinContent"].mean(),
}

# %%
# Out:
# <function dict.values>

# %%
example = [list(promedios.values())]
example[0][0] =  100
example = scaler.transform(np.array(example))

vecinos = model.kneighbors(example, return_distance=False)

# %%
data.iloc[vecinos[0]]
# Out:
#         RecipeId TotalTime  RecipeCategory
# 67192     119729      PT1H    Lunch/Snacks  \
# 150063    255542     PT40M    Pasta Shells
# 263170    439516   PT6H15M  Very Low Carbs
# 301940    501542      PT1H         Chicken
# 5339       10925     PT50M       < 60 Mins
#
#                                                  Keywords
# 67192   ['Cheese', 'Cauliflower', 'Vegetable', 'Meat',...  \
# 150063    ['Spaghetti', 'Vegetable', '< 60 Mins', 'Easy']
# 263170                                            ['asy']
# 301940           ['Poultry', 'Meat', '< 60 Mins', 'Oven']
# 5339                                              ['asy']
#
#                                RecipeIngredientQuantities
# 67192   ['20', 'NA', 'NA', '1', '8', '2', '1', '2', '1...  \
# 150063  ['12', '4', '1', '1/2', '1', '4', '1/2', '1/2'...
# 263170  ['1/2', '2', '1/4', '1', '1', '1/4', '1/4', '1...
# 301940  ['1', '3', '1', '3/4', '1/4', '1', '1', '1/2',...
# 5339                         ['1', '1/2', '1', 'NA', '6']
#
#                                     RecipeIngredientParts  Calories
# 67192   ['cauliflower', 'butter', 'ground beef', 'toma...     216.7  \
# 150063  ['jumbo pasta shells', 'bacon', 'butter', 'mus...     196.6
# 263170  ['onion', 'ground beef', 'ground turkey', 'chi...     213.9
# 301940  ['chicken', 'unsalted butter', 'red onion', 'c...     216.4
# 5339    ['frozen chopped spinach', 'gorgonzola', 'egg'...     181.6
#
#         FatContent  SaturatedFatContent  CholesterolContent  SodiumContent
# 67192         13.8                  6.4                53.4          572.9  \
# 150063        12.6                  6.7                65.5          598.7
# 263170        14.8                  6.3                51.4          468.0
# 301940        15.9                  6.7                61.3          349.0
# 5339          12.5                  7.6                63.6          601.0
#
#         CarbohydrateContent  FiberContent  SugarContent  ProteinContent
# 67192                   8.0           3.1           3.6            16.3  \
# 150063                  7.6           2.5           2.8            14.7
# 263170                  5.9           2.6           2.1            16.3
# 301940                  6.2           3.0           2.0            12.6
# 5339                    6.7           3.9           1.8            12.9
#
#         RecipeServings
# 67192              8.0
# 150063             6.0
# 263170            12.0
# 301940             8.0
# 5339               6.0
